# %% [markdown]
# <a href="https://colab.research.google.com/github/whynot285088/linux_command/blob/main/linux_command.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #리눅스 파일 다운 링크
# https://www.kernel.org/pub/linux/

# %% [markdown]
# #프롬프트가 #이면 root 사용자
#
# #프롬프트가 $면   일반 사용자

# %% [markdown]
# #종료
# poweroff
#
# #시스템 재부팅
# reboot
#
# #로그아웃
# logout 또는 exit

# %% [markdown]
# #가상 콘솔
# 가상 콘솔로 이동 단축키는 Ctrl+ Alt + F2 ~ F6
#
# (Ctrl + Alt + F2는 X윈도우 모드)
#
# server tty 숫자 (숫자는 가상모니터 번호)
#
# 콘솔 입력 이동은 chvt 숫자 입력

# %% [markdown]
# #종료 설정
# shutdown -h +5
#
# (5분 뒤 컴퓨터 끄기)
# (가상모니터 전환하면 종료 시간 뜸.)
#
# (자료 날아갈 수 있으면 그 전에 정리 및 저장하기)
#
#
# #종료 메세지만 보내는 법(가짜 종료)
# shutdown -k +10
#
# #예약 종료 취소
# shutdown -c (종료와 가짜 종료 둘다 취소 가능)

# %% [markdown]
# #tree
# 디렉토리 구조를 트리 형태로 시각적으로 보여주는 명령어야. 파일과 폴더의 계층 구조를 한눈에 보기 좋게 출력해줘서 프로젝트 구조 파악할 때 유용
#
# tree (현재 디렉토리를 기준으로 모든 하위 폴더와 파일을 트리 형태로 출력)
#
# # tree 예시
#
# tree /path/to/directory (특정 디렉토리 보기)
#
# tree -L 2 (깊이 제한, 설명 : 2단계까지만 출력)
#
# tree -f (파일만 보기, 파일 경로까지 포함해서 출력)
#
# tree -d (파일만 보기, 디렉토리만 출력)
#
# tree -a (숨김 파일 포함)
#
# tree -h (용량 표시, 파일 크기를 사람이 읽기 쉽게 표시)
#
# tree -I "node_modules" (특정 패턴 제외, node_modules 제외)
#
# tree > structure.txt (결과를 파일로 저장,)
#
#
# sudo apt install tree (설치X)(Ubuntu / Debian)
#
#
# brew install tree (설치X) (macOS (Homebrew))
# 예시 출력
#
# .
#
# ├── src
#
# │   ├── main.js
#
# │   └── utils.js
#
# ├── package.json
#
# └── README.md

# %% [markdown]
# #Ctrl+c 실행 취소

# %% [markdown]
# # ls (중요O)
# Windows의 dir과 같은 역할로,해당 디렉터리에 있는 파일의 목록을 나열
#
# 예) # ls /etc/systemd
#
# # cd (중요O)
# 디렉터리를 이동
#
# 예) # cd ../etc/systemd
#
# #pwd (중요O)
# 현재 디렉터리의 전체 경로를 출력
#
# #touch (중요O)
# 크기가 0인 새 파일을 생성, 이미 존재하는 경우 수정 시간을 변경
#
# 예) # touch abc.txt
#
# #rm (중요O)
# 파일이나 디렉터리를 삭제
#
# 예) # rm -rf abc
#
# #cp (중요O)
# 파일이나 디렉터리를 복사
#
# 예) # cp abc.txt cba.txt
#
# #mv (중요O)
# 파일과 디렉터리의 이름을 변경하거나 위치 이동 시 사용
#
# 예) mv abc.txt www.
#
# #mkdir (중요O)
# 새로운 디렉터리를 생성
#
# 예) # mkdir abc
#
# #rmdir
# 디렉터리를 삭제. (단, 비어 있어야 함)
#
# 예) # rmdir abc
#
# #cat (중요O)
# 텍스트로 작성된 파일을 화면에 출력
#
# 예) # cat a.txt b.txt
#
# #head, tail
# 텍스트로 작성된 파일의 앞 10행 또는 마지막 10행만 출력
#
# 예) # head /etc/systemd/user.conf
#
# #more
# 텍스트로 작성된 파일을 화면에 페이지 단위로 출력
#
# 예) # more /etc/systemd/system.conf
#
# #less
# more와 용도가 비슷하지만 기능이 더 확장된 명령
#
# 예) # less /etc/systemd/system.conf
#
# #file (중요O)
# File이 어떤 종류의 파일인지를 표시
#
# 예) # file /etc/systemd/system.conf
#
# #clear
# 터미널 화면을 깨끗하게 지워줌
#
# 예) # clear

# %% [markdown]
# #런레벨(Runlevel) (중요x)
# init 명령어 뒤에 붙는 숫자
#
# 0 → 시스템 종료 (Power Off)
#
# 1 → 단일 사용자 모드 (Rescue)(관리자용, 복구/점검)
#
# 2 → 다중 사용자 (Multi-User)(네트워크 없이)(사용X)
#
# 3 → 다중 사용자 + 네트워크 (Multi-User)(CLI 환경)
#
# 4 → 사용자 정의 (Multi-User)(거의 사용X)
#
# 5 → GUI 포함 (Graphical)(우분투에서 우리가 보는 화면)
#
# 6 → 재부팅 (Reboot)
#
# 런레벨 모드를 확인하려면 /lib/systemd/system 디렉터리의 runlevel?.target 파일을 확인

# %% [markdown]
# # Tab 자동완성 (Auto Completion)
#
# 명령어나 파일 이름을 일부만 입력하고 Tab 키를 누르면 자동으로 완성해주는 기능
#
# 후보가 여러 개면 Tab 두 번 → 목록 보여줌

# %% [markdown]
# # history (명령어 기록)
#
# history → 지금까지 입력한 명령어 목록 출력
#
# !10 → history에서 10번 명령 다시 실행
#
# !! → 바로 직전 명령 재실행
#
# ↑↓ 도스 방향키 → 이전 명령어 탐색
#
# Ctrl + R → 검색

# %% [markdown]
# ## 텍스트 편집기
# 요약표
# | 편집기| 방식   | 난이도 | 특징       |
# | ----- | ---    | ---    | -------- |
# | gedit | GUI    | 쉬움  | 메모장 느낌   |
# | nano  | 터미널 | 쉬움  | 초보자용 CLI |
# | vi    | 터미널 | 어려움 | 전문가용     |
#
# # gedit
# GUI 기반 (마우스로 쓰는 메모장 느낌)
#
# 서버(SSH) 환경에서는 사용 어려움
# 가볍지 않음
#
# ✔ 이런 상황에 추천
# → “지금 VMware에서 화면 보면서 편하게 수정하고 싶다”
#
# # nano
#
# 터미널 기반 + 쉬운 조작
#
# 화면 아래에 단축키 안내가 있음
# 배우기 쉬움
# 방향키, 입력 다 자연스럽게 됨
#
# ✔ 단축키
#
# 1. 저장: Ctrl + O
#
# 2. 제목저장: 그냥 엔터 누르면 됨
#
# 3. 종료: Ctrl + X
#
# ✔ 이런 상황에 추천
# → “터미널에서 간단하게 파일 수정하고 싶다”
#
# # vi (또는 vim)
#
# 터미널 기반 + 강력하지만 어려움
#
# 모드 개념 있음 (입력 모드 / 명령 모드)
# 처음엔 매우 불편함
# 대신 숙달되면 가장 빠르고 강력
#
# ✔ 이런 상황에 추천
# → “리눅스 제대로 다룰 거면 필수”
#
# 입력 시작: i
#
# 저장: :w
#
# 종료: :q
#
# 저장 후 종료: :wq
#
# 1️⃣ 명령모드 → 입력모드
# | 키 | 설명               |
# | - | ---------------- |
# | i | 현재 커서 위치부터 입력 |
# | I | 현재 줄의 맨 앞에서부터 입력 |
# | a | 현재 커서 다음 칸부터 입력  |
# | A | 현재 줄의 맨 끝에서부터 입력|
#
# 2️⃣ 명령 모드에서 커서 이동
# | 키 | 설명        |
# | - | ------------ |
# | h | 왼쪽으로 한 칸 이동 (방향키 ⬅️) |
# | j | 아래로 한 칸 이동 (방향키 ⬇️)  |
# | k | 위로 한 칸 이동 (방향키 ⬆️) |
# | l | 오른쪽으로 한 칸 이동 (방향키 ➡️) |
#
# 3️⃣ 명령 모드에서 삭제 / 복사 / 붙여넣기
# | 명령어     | 설명                        |
# | ------- | ------------------------- |
# | x       | 현재 커서 위치의 글자 삭제 (Del)     |
# | X       | 현재 커서 앞 글자 삭제 (Backspace) |
# | dd      | 현재 커서가 있는 행 삭제            |
# | 숫자 + dd | 입력한 숫자만큼 행 삭제 (숫자 다음 dd)|
# | yy      | 현재 행 복사                   |
# | 숫자 + yy | 입력한 숫자만큼 행 복사 (숫자 다음 yy)|
# | p       | 현재 행 이후에 붙여넣기             |
# | P       | 현재 행 이전에 붙여넣기             |
#
# 문자열을 치환은 “:%s/기존문자열/새문자열”
# 행번호 표시는 “:set number”

# %% [markdown]
# # man
# 리눅스에서 명령어 사용법을 보여주는 공식 설명서(매뉴얼)를 여는 명령어
#
# ex) man ls → ls 명령어 설명서 열림
#
# ✔ 화면에서 하는 조작
#
# ↑ ↓ 또는 PageUp / PageDown → 스크롤
#
# /단어 → 검색 (예: /option)
#
# n → 다음 검색 결과
#
# q → 종료

# %% [markdown]
# # **사용자와 그룹 관련 명령어**
# # adduser
# 새로운 사용자를 추가
#
# 예) # adduser newuser1
#
# # passwd
# 사용자의 비밀번호를 지정하거나 변경
#
# 예) # passwd newuser1
#
# # usermod
# 사용자의 속성을 변경
#
# 예) # usermod --groups ubuntu newuser1
#
# # userdel
# 사용자를 삭제
#
# 예) # userdel newuser2
#
# # chage
# 사용자의 암호를 주기적으로 변경하도록 설정
#
# 예) # chage -m 2 newuser1
#
# # groups
# 현재 사용자가 속한 그룹을 보여줌
#
# 예) # groups
#
# # groupadd
# 새로운 그룹을 생성
#
# 예) # groupadd newgroup1
#
# # groupmod
# 그룹의 속성을 변경
#
# 예) # groupmod --new-name mygroup1 newgroup1
#
# # groupdel
# 그룹을 삭제
#
# 예) # groupdel newgroup2
#
# # gpasswd
# 그룹의 암호를 설정하거나, 그룹의 관리를 수행
#
# 예) # gpasswd mygroup1

# %% [markdown]
# # **파일과 디렉터리의 소유와 허가권**
# # 파일 유형
# ▫ 디렉터리일 경우에는 d, 일반적인 파일일 경우에는 -가 표시
# # 파일 허가권(Permission)
# ▫ “rw-” , “r--” , “r--” 3개씩 끊어서 읽음 (r은 read, w는 write, x는 execute 의 약자)
#
# 1. 첫 번째 “rw-”는 소유자(User)의 파일접근 권한
# 2. 두 번째의 “r--”는 그룹(Group)의 파일접근 권한
# 3. 세 번째의 “r--”는 그 외의 사용자(Other)의 파일접근 권한
#
# ✔ 숫자 표시
# | 항목 | 소유자(User) | 그룹(Group) | 기타 사용자(Other) |
# |------|-------------|-------------|--------------------|
# | r    | 4           | 4           | 4                  |
# | w    | 2           | 0           | 0                  |
# | x(-) | 0           | 0           | 0                  |
# | 합계 | 6           | 4           | 4                  |
#
# 즉, 이 표는 644 권한을 의미
#
#
# # chmod 명령
# ▫ 파일 허가권 변경 명령어
#
# ▫ 예) # chmod 777 sample.txt
#
# # 파일 소유권(Ownership)
# ▫ 파일을 소유한 사용자와 그룹을 의미
#
# # chown/chgrp 명령
# ▫ 파일의 소유권을 바꾸는 명령어
#
# ▫ 예) # chown ubuntu:ubuntu sample.txt 또는
#
#     # chown ubuntu sample.txt 및 # chgrp ubuntu sample.txt

# %% [markdown]
# # **링크**
# | 구분     | 하드 링크    | 심볼릭 링크      |
# | ------ | -------- | ----------- |
# | 개념     | 같은 파일 공유 | 파일을 가리키는 경로 |
# | 원본 삭제  | 영향 없음    | 링크 깨짐       |
# | 파일 시스템 | 같은 곳만 가능 | 다른 곳도 가능    |
# | 디렉터리   | 거의 불가    | 가능          |
# | 느낌     | 진짜 복제    | 바로가기        |
# ||
#
# 1. 하드 링크 (Hard Link)
#
# 👉 같은 파일(데이터)을 가리키는 또 다른 이름 ( → “파일 자체를 같이 씀”)
#
# 특징
# 원본 파일과 완전히 동일한 파일 취급
# 실제로는 같은 데이터를 공유 (inode 공유)
# 원본을 지워도 하드 링크로 접근 가능
# 같은 파일 시스템 내에서만 생성 가능
# 디렉터리에는 보통 생성 불가
# 예시
# ln file1 file2
#
# → file1, file2는 사실상 같은 파일
#
# ✔ 느낌
# → “복사한 것 같지만 실제로는 하나를 같이 쓰는 상태”
#
# 2. 심볼릭 링크 (Symbolic Link / Soft Link)
#
# 👉 다른 파일을 가리키는 ‘바로가기’(→ “파일을 가리키는 포인터”)
#
# 특징
# 실제 데이터가 아니라 경로를 저장
# 원본 파일이 삭제되면 → 링크 깨짐 (dangling)
# 다른 파일 시스템도 연결 가능
# 디렉터리도 링크 가능
# 예시
# ln -s file1 link1
#
# → link1은 file1을 가리키는 바로가기
#
# ✔ 느낌
# → “윈도우 바로가기(.lnk) 같은 개념”

# %% [markdown]
# # **편리한 패키지 설치를 위한 apt**
# # apt 명령
# ▫ dpkg 명령의 패키지 의존성 문제를 완전하게 해결됨.
#
# ▫ 인터넷을 통하여 필요한 파일을 저장소(Repository)에서 자동으로 모두
# 다운로드해서 설치하는 방식
#
#     저장소의 URL은/etc/apt/sources.list.d/ubuntu.sources 파일
#
# # apt 기본적인 사용법
# 1. 기본 설치 : apt -y install 패키지이름
#
#     “-y”는 사용자의 확인을 모두 “yes”로 간주하고 설치를 진행한다는 옵션
#
# 2. 패키지 목록의 업데이트 : apt update
# 3. 삭제 : apt remove/purge 패키지 이름
# 4. 사용하지 않는 패키지 제거 : apt autoremove
# 5. 내려 받은 파일 제거 : apt clean 또는 apt autoclean
#
# # apt-cache
# 1. 패키지를 설치하기 전에 패키지에 대한 정보나 의존성 문제를 미리 확인
# 2. 패키지 정보 보기
#
#      apt-cache show 패키지이름
# 3. 패키지 의존성 확인
#
#      apt-cache depends 패키지이름
#
# 4. 패키지 역의존성 확인
#
#      apt-cache rdepends 패키지이름
#
# # 우분투 패키지 저장소
# ▫ main : 우분투에서 공식적으로 지원하는 무료(Free) SW
#
# ▫ restricted : 우분투에서 공식적으로 지원하는 유료(Non-Free) SW
#
# ▫ universe : 우분투에서 지원하지 않는 무료(Free) SW
#
# ▫ multiverse : 우분투에서 지원하지 않는 유료(Non-Free) SW
#
# # 저장소가 기록된 파일
# ▫ /etc/apt/sources.list.d/ubuntu.sources 파일
#
# ▫ 원본 : Suites: noble noble-updates noble-backports
#
#     noble ➡️ 원본 패키지
#     noble-updates 및 noble-backports
#     ➡️ 업데이트 패키지

# %% [markdown]
# # **프로그램 설치를 위한 dpkg**
# # dpkg(Debian Package)
# ▫ Windows의 “setup.exe”와 비슷한 설치 파일
#
# ▫ 확장명은 *.deb이며, 이를 패키지(Package)라고 부름.
#
# ex)
#
#     galculator_2.1.4-1.2_amd64.deb
# 패키지이름_버전-개정번호_아키텍처.deb
# 1. 패키지이름 : galculator → 패키지(프로그램)의 이름
# 2. 버전 : 2.1.4 → 대개 3자리수로 구성. 주버전, 부버전, 패치버전
# 3. 개정번호 : 1.2 → 문제점을 개선할 때마다 붙여지는 번호
# 4. 아키텍처 : amd64 → 인텔/AMD 64비트 CPU를 의미
#
# # **dpkg 명령어**
#
# # ▫ 설치
#
#  dpkg -i 패키지파일이름.deb
#
# # ▫ 삭제
#  dpkg -r 패키지이름
#  dpkg -P 패키지이름  설정파일까지 삭제
# # ▫ 패키지 조회
#  dpkg -l 패키지이름 → 설치된 패키지에 대한 정보를 보여줌
#  dpkg -L 패키지이름 → 패키지가 설치한 파일 목록을 보여줌
# # ▫ 아직 설치되지 않은 deb 파일 조회
#  dpkg --info 패키지파일이름.deb → 패키지 파일에 대한 정보를 보여줌
#
#     dpkg 명령의 단점
#      ▫‘의존성’ 문제
#          A패키지가 설치되기 위해서 B패키지가 필요할 경우, dpkg 명령으로는 해결이 까다로움.
#      ▫ 이를 해결하기 위해 apt가 등장함

# %% [markdown]
# # **파일의 압축과 묶기 **
# •파일 압축
# ▫ 압축파일 확장명은 xz, bz2, gz, zip, Z 등
# ▫ xz나 bz2 압축률이 더 좋음
# •파일 압축 관련 명령
# ▫ xz : 확장명 xz로 압축을 하거나 풀어준다
# 예) xz 파일명
# xz -d 파일명.xz
# ▫ bzip2 : 확장명 bz2로 압축을 하거나 풀어준다
# 예) bzip2 파일명
# bzip2 -d 파일명.bz2
# ▫ gzip : 확장명 gz으로 압축을 하거나 풀어준다
# 예) gzip 파일명
# gzip -d 파일명.gz
# ▫ zip/unzip : 확장명 zip으로 압축하거나 풀어준다.
# 예) zip 새로생성될파일이름.zip 압축할파일이름
# unzip 압축파일이름.zip
# •파일 묶기
# ▫ 리눅스(유닉스)에서는 ‘파일 압축’과 ‘파일 묶기’는 원칙적으로 별개의 프
# 로그램으로 수행
# ▫ 파일 묶기의 명령어는 ‘tar’이며, 묶인 파일의 확장명도‘tar’이다
# •파일 묶기 명령(tar)
# ▫ tar : 확장명 tar로 묶음 파일을 만들어 주거나 묶음을 풀어 준다
# 동작 : c(묶기), x(풀기), t(경로확인), C(디렉터리 지정)
# 옵션 : f(파일), v(과정보이기), J(tar+xz), z(tar+gzip), j(tar+bzip2)
#
#     ▫ 사용 예
#     tar cvf my.tar /etc/systemd/ → 묶기
#     tar cvfJ my.tar.xz /etc/systemd/ → 묶기 + xz 압축
#     tar xvf my.tar → tar 풀기
#     tar xvfJ my.tar.xz → xz 압축 해제 + tar 풀기

# %% [markdown]
# # **파일 위치 검색**
# # find [경로] [옵션] [조건] [action] : 기본 파일 찾기
# ▫ [옵션] -name, -user(소유자), -newer(전,후), -perm(허가권), -size(크기)
#
# ▫ [action] -print(디폴트), -exec (외부명령 실행)
#
#     ▫ 사용 예
#     find /etc -name "*.conf“
#     find /bin -size +10k -size -100k
#     find /home -name "*.swp" -exec rm { } \;
#
# •which 실행파일이름 : PATH에 설정된 디렉터리만 검색
#
# •whereis 실행파일이름 :실행 파일,소스,man페이지 파일까지 검색
#
# •locate 파일이름 : 파일 목록 데이터베이스에서 검색

# %% [markdown]
# # **시스템 설정**
#
# # •네트워크 설정 (nmtui)
#
# # •방화벽 설정(ufw, gufw)
#
# # •cron
# ▫ 주기적으로 반복되는 일을 자동적으로 실행될 수 있도록 설정
#
# ▫ 관련된 데몬(서비스)은“crond” , 관련 파일은 “/etc/crontab”
#
# ▫ /etc/crontab 형식
#
#  분 시 일 월 요일 사용자 실행명령
#
#      예) 00 05 1 * * root cp -r /home /backup
#
# # •at
# ▫ 일회성 작업을 예약
#
#     ▫ 사용 예
#      예약 : # at <시간>
#      예) # at 3:00am tomorrow → 내일 새벽 3시
#             # at now + 1 hours → 1시간 후
#      at> 프롬프트에 예약 명령어 입력 후 [Enter]
#      완료되면 [Ctrl] + [D]
#      확인 : # at -l
#      취소 : # atrm <작업번호>

# %% [markdown]
# # **네트워크 관련 필수 개념**
# # •TCP/IP
# ▫ 컴퓨터끼리 네트워크 상으로 의사소통을 하는 “프로토콜” 중 가장 널리 사
# 용되는 프로토콜의 한 종류
#
# # •호스트 이름(Hostname)과 도메인 이름(Domain name)
# ▫ 호스트 이름은 각각의 컴퓨터에 지정된 이름
#
# ▫ 도메인 이름(또는 도메인 주소)는 hanbit.co.kr과 같은 형식
#
# # •IP 주소
# ▫ 각 컴퓨터의 랜카드에 부여되는 중복되지 않는 유일한 주소
#
# ▫ 4바이트로 이루어져 있으며, 각 자리는 0~255까지의 숫자
#
# ▫ 예) Server의 IP 주소는 192.168.111.100
#
# # •네트워크 주소
# ▫ 같은 네트워크에 속해 있는 공통된 주소 (예 : 192.168.111.0)
#
# # •브로드캐스트(Broadcast) 주소
# ▫ 내부 네트워크의 모든 컴퓨터가 듣게 되는 주소
#
# ▫ 현재 주소의 제일 끝자리를 255로 바꾼 주소(C클래스)
#
# # •게이트웨이(Gateway), 라우터(Router)
# ▫ 라우터 == 게이트웨이
#
# ▫ 네트워크 간에 데이터를 전송하는 컴퓨터 또는 장비
#
# ▫ VMware의 게이트웨이 주소는 192.168.111.2로 고정
#
# # •넷마스크(Netmask) & 클래스(Class)
# ▫ 넷마스크 : 네트워크의 규모를 결정(예:255.255.255.0  C클래스)
#
# # •DNS(Domain Name System) 서버(= 네임 서버) 주소
# ▫ URL을 해당 컴퓨터의 IP주소로 변환해 주는 서버
#
# ▫ 설정 파일은 /etc/resolv.conf
#
# ▫ VMware를 사용하면 VMware가 192.168.111.2를 게이트웨이 및
#
# DNS 서버로, 192.168.111.254를 DHCP 서버로 설정함.
#
# # •리눅스에서의 네트워크 장치 이름
# ▫ 우분투는 랜카드를 ens32 또는 ens33으로 할당함
#
#     ▫ 명령 예
#      # ifconfig ens32 또는 ens33 → 네트워크 설정 정보를 출력
#      # ifdown ens32 또는 ens33 → 네트워크 장치를 정지
#      # ifup ens32 또는 ens33 → 네트워크 장치를 가동

# %% [markdown]
# # **프로세스**
# 정의 : 하드디스크에 저장된 실행코드(프로그램)가, 메모리에 로딩되어 활성화된 것
#
# # •포그라운드 프로세스(Foreground Process)
#
#     ▫ 실행하면 화면에 나타나서 사용자와 상호작용을 하는 프로세스
#     ▫ 대부분의 응용프로그램
#
# # •백그라운드 프로세스(Background Process)
#
#     ▫ 실행은 되었지만, 화면에는 나타나지 않고 실행되는 프로세스
#     ▫ 백신 프로그램, 서버 데몬 등
#
# # •프로세스 번호
#     ▫ 각각의 프로세스에 할당된 고유번호
#
# # •작업 번호
#
#     ▫ 현재 실행되고 있는 백그라운드 프로세스의 순차번호
#
# # •부모 프로세스와 자식 프로세스
#
#     ▫ 모든 프로세스는 부모 프로세스를 가지고 있음
#     ▫ 부모 프로세스를 kill 하면, 자식 프로세스도 자동으로 kill 됨
#
# # •프로세스 관련 명령
# ▫ ps
#
#      현재 프로세스의 상태를 확인하는 명령어
#      “ps -ef | grep <프로세스 이름>”을 주로 사용함
#
# ▫ kill
#
#      프로세스를 강제로 종료하는 명령어
#      “kill -9 <프로세스 번호>”는 강제 종료
#
# ▫ pstree
#
#      부모 프로세스와 자식 프로세스의 관계를 트리 형태로 보여 줌

# %% [markdown]
# # **중요한 네트워크 관련 명령어**
# # •파이프(pipe)
# ▫ 2개의 프로그램을 연결해 주는 연결통로의 의미
#
# ▫“|”문자를 사용함
#
# ▫ 예) # ls -l /etc | less
#
# # •필터(filter)
# ▫ 필요한 것만 걸러 주는 명령어
#
# ▫ grep, tail, wc, sort, awk, sed 등
#
# ▫ 주로 파이프와 같이 사용
#
# ▫ 예) # ps -ef | grep bash
#
# # •리디렉션 (redirection)
# ▫ 표준 입출력의 방향을 바꿔 줌
#
#     ▫ 예) ls -l > list.txt
#         sort < list.txt > out.txt
#
#
#
#
#
#
# #  •nm-connection-editor 또는 nmtui
#   ▫ 네트워크와 관련된 대부분의 작업을 이 명령어에서 수행
#
#     •자동 IP 주소 또는 고정 IP주소 사용 결정
#     •IP주소, 서브넷 마스크, 게이트웨이 정보 입력
#     •DNS 정보 입력
#     •네트워크 카드 드라이버 설정
#     •네트워크 장치(ens32)의 설정
#
# # •systemctl <start/stop/restart/status> NetworkManager
# ▫ 네트워크의 설정을 변경한 후에, 변경된 내용을 시스템에 적용시키는 명령어
#
# # •ifconfig <장치이름> 또는 ip addr
# ▫ 장치의 IP주소 설정 정보를 출력
#
# # •nslookup
# ▫ DNS 서버의 작동을 테스트하는 명령어
#
# # •ping <IP주소 또는 URL>
# ▫ 해당 컴퓨터가 네트워크상에서 응답하는지를 테스트하는 간편한 명령어

# %% [markdown]
# # **네트워크 설정과 관련된 주요 파일**
# # •네트워크 기본 정보가 설정된 파일
# ▫ /etc/netplan/*.yaml 파일
#
#      Server : 90-NM-~~~.yaml
#      Server(B) : 50-cloud-init.yaml
#
# # •/etc/resolv.conf
# ▫ DNS 서버의 정보 및 호스트 이름이 들어 있는 파일
#
#     영구적으로 DNS 서버 정보를 변경하려면 nm-connection-editor 명령이나 /etc/netplan/*.yaml 파일을 직접 편집해야 함
#
# # •/etc/hosts
# ▫ 현 컴퓨터의 호스트 이름 및 FQDN이 들어 있는 파일

# %% [markdown]
# # 코드 실행해보기

# %%
# !ls
# Out:
# sample_data

# %%
# !uname -a
# Out:
# Linux 9e0455c2ef25 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux

# %%
# !find

# %%
파일이나 디렉터리를 “조건으로 검색”하는 명령어

# %%
tar

# %%
ifconfig

# %%
ping

# %%
nslookup

# %%
|

# %%
>

# %%
ps -ef

# %%
grep

# %%
kill

# %%
&

# %%
ls
cd
pwd
touch
rm
cp
mv
mkdir
rmdir
cat
head
tail
more
less
file
clear
history
gedit
nano
vi
man
chmod
chown
ln -s
dpkg
apt install
apt update //목록을 update
apt upgrade //기설치된 패키지를 업그레이드
tar cvfJ
tar xvfJ
find
ifconfig  : 윈도우에서는 cmd창에서 ipconfig
nslookup
ping
|
>
ps -ef
kill -9 PID
systemctl start|stop|restart|status
uname -a
make : Makefile(여러 소스에 대한 컴파일정보를 포함)
sudo 명령어
fdisk
mkfs.ext4
mount
umount
df -h
echo
export
printenv
telnet

apt install openssh-server
systemctl enable ssh
systemctl restart ssh
ufw allow 22/tcp
ssh ubuntu@192.168.111.100

apt install xrdp
systemctl restart xrdp
ufw allow 3389/tcp
